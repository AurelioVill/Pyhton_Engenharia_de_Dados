# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#importando apenas o pandas não consegui ler o arquivo, a biblioteca deve ter atualizado, com isso tive que instalar a biblioteca abaixo
#utilizando o codigo pip install openpyxl e logo após importar a biblioteca
import pandas as pd

# %%
# Biblioteca importada para leitura do arquivo abaixo
import openpyxl as op

# %%
#Função pandas para leitura do arquivo Excel abaixo
df = pd.read_excel(r"C:\Users\Usuário\Documents\Arquivos_Python_Engenharia_Dados\Origem\arquivos_excel\Produto.xlsx")
df.head(15) #head para adicionar o numero de linhas que quero visualizar
# Out:
#     ID                  Name  Price  Id_Category
# 0    0       Sapato vermelho     96            0
# 1    1  Bolsa mais que Velha   8000            0
# 2    2                 Calça     75            0
# 3    3    Camisa apertadinha    170            0
# 4    4   Vestido Super curto     57            0
# 5    5               Perfume     29            1
# 6    6      Creme de Barbear     15            1
# 7    7       Hidratante caro    800            1
# 8    8               Shampoo     15            1
# 9    9        Protetor Solar     11            1
# 10  10             Geladeira   1952            2
# 11  11                 Fogão   1373            2
# 12  12                    TV   1992            2
# 13  13      Máquina de Lavar   1826            2
# 14  14      Máquina de Secar   1774            2

# %%
#Dataframe utilizado para localizar Calça que se encontra na coluna Name
df_calca = df.loc[df['Name'] == 'Calça']

# %%
#Chamando a Dataframe para visualizar o dado requerido acima
df_calca
# Out:
#    ID   Name  Price  Id_Category
# 2   2  Calça     75            0

# %%
#Criando uma variavel com os itens que quero para chamar no Dataframe abaixo 
#Podendo ta,bém utilizar da forma abaixo, numa mesma linha de codigo
#df_itens = df.loc[df['Name'].isin(['Sapato vermelho', 'Calça', 'Perfume', 'Shampoo'])]

itens = ['Sapato vermelho', 'Calça', 'Perfume', 'Shampoo']
df_itens = df.loc[df['Name'].isin(itens)]

# %%
df_itens
# Out:
#    ID             Name  Price  Id_Category
# 0   0  Sapato vermelho     96            0
# 2   2            Calça     75            0
# 5   5          Perfume     29            1
# 8   8          Shampoo     15            1

# %%
#Criando df para localizar o Price (preço) mais que mil reais
dfmais1000 = df.loc[df['Price'] > 1000]

# %%
#Adicionando o .head() ao lado da função, ele le apaneas o top 5
dfmais1000.head()
# Out:
#     ID                  Name  Price  Id_Category
# 1    1  Bolsa mais que Velha   8000            0
# 10  10             Geladeira   1952            2
# 11  11                 Fogão   1373            2
# 12  12                    TV   1992            2
# 13  13      Máquina de Lavar   1826            2

# %%
#Chamando os preços maiores e iguais a 500 e menores e iguais a 1000
df500a1000 = df.loc[(df['Price'] >= 500) & (df['Price'] <= 1000)]
df
# Out:
#     ID                  Name  Price  Id_Category
# 0    0       Sapato vermelho     96            0
# 1    1  Bolsa mais que Velha   8000            0
# 2    2                 Calça     75            0
# 3    3    Camisa apertadinha    170            0
# 4    4   Vestido Super curto     57            0
# 5    5               Perfume     29            1
# 6    6      Creme de Barbear     15            1
# 7    7       Hidratante caro    800            1
# 8    8               Shampoo     15            1
# 9    9        Protetor Solar     11            1
# 10  10             Geladeira   1952            2
# 11  11                 Fogão   1373            2
# 12  12                    TV   1992            2
# 13  13      Máquina de Lavar   1826            2
# 14  14      Máquina de Secar   1774            2
# 15  15   O Romance Exagerado     46            3
# 16  16       Suspense Demais     42            3
# 17  17  Terror Aterrorizante     45            3
# ...

# %%
#Chamando a função criada a cima mas colocando o top 1000 da planilha que entram nessa regra
df500a1000.head(1000)
# Out:
#     ID               Name  Price  Id_Category
# 7    7    Hidratante caro    800            1
# 35  35         Video-Game    602            7
# 39  39  Secador de Cabelo    580            7
