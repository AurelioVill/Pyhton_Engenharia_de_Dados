# %%
import pandas as pd

# %%
import openpyxl as op

# %%
#Chamando o arquivo .csv adicionando o delimitador como ',' chamando os 5 primeiros com o df.head()
df = pd.read_csv(r"C:\Users\Usuário\Documents\Arquivos_Python_Engenharia_Dados\Origem\arquivos_csv\Clientes.csv", delimiter=',')
df.head(1000)
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Filtrando apenas o estado de Mato Grosso
estado = df.loc[df['state'] == 'Mato Grosso']
estado
# Out:
#     id           created_at first_name last_name                    email  \
# 3    3  2018-01-17 03:02:58    Daniela   Avelino      daniela@exemplo.com
# 12  12  2018-03-28 00:24:00      Carol   Barboza        carol@exemplo.com
# 15  15  2018-11-15 18:00:53  Stephanie   Barbosa    stephanie@usuario.com
# 66  66  2018-10-18 04:31:59  Stephanie     Abreu  stephanie@meu_email.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa     cibele@meu_email.com
#
#      cell_phone country        state                          street  number  \
# 3   9 4642-9486  Brasil  Mato Grosso                             NaN     NaN
# 12  9 8487-3501  Brasil  Mato Grosso    Rua 31 do Estado Mato Grosso     1.0
# 15  9 1446-3560  Brasil  Mato Grosso                             NaN     NaN
# 66  9 6466-2389  Brasil  Mato Grosso    Rua 19 do Estado Mato Grosso    53.0
# 98  9 4211-6968  Brasil  Mato Grosso  Praça 75 do Estado Mato Grosso    24.0
#
#     additionals
# 3           NaN
# 12  Conjunto 23
# ...

# %%
#Criando uma variavel com o estados que quero pesquisar e chamando a mesma no codigo abaixo
estados = ['Rio de Janeiro', 'Mato Grosso', 'Paraiba', 'São Paulo']
df_estados = df.loc[df['state'].isin(estados)]
df_estados.head(20)
# Out:
#     id           created_at first_name last_name                    email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes      frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino      daniela@exemplo.com
# 12  12  2018-03-28 00:24:00      Carol   Barboza        carol@exemplo.com
# 15  15  2018-11-15 18:00:53  Stephanie   Barbosa    stephanie@usuario.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva    adalberto@usuario.com
# 43  43  2018-01-07 07:54:22    Daniela      Lima                      NaN
# 47  47  2018-09-01 23:00:40      Júlia    Castro        júlia@exemplo.com
# 55  55  2018-07-10 18:40:07   Gabriela     Pires   gabriela@meu_email.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire    stephanie@usuario.com
# 65  65  2018-02-06 05:56:36    Willian   Freitas                      NaN
# 66  66  2018-10-18 04:31:59  Stephanie     Abreu  stephanie@meu_email.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz        laura@exemplo.com
# ...

# %% [markdown]
# Dados nulos

# %%
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Utilizando o fillna para substituir as informações que estão nulas, adicionando o 'Não informado'
df['email'] =   df['email'].fillna('Não informado')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus         Não informado
# 1    1  2017-10-16 00:50:39      Luana   Almeida         Não informado
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira         Não informado
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Utilizando o fillna para substituir as informações que estão nulas, adicionando o 'Não informado'
df['state'] =   df['state'].fillna('Não informado')
df['street'] =   df['street'].fillna('Não informado')
df['additionals'] =   df['additionals'].fillna('Não informado')

#Dessa forma consigo realizar o tratamento de varias colunas de uma vez, criando uma lista de colunas anteriormente e chamando a mesma no dataframe abaixo, colocando a informação que dev ser alterada 
info_null = ['state', 'street', 'additionals', 'number']
dfInfoNull = df[info_null].fillna('Não informado')
dfInfoNull
# Out:
#                 state                                  street    additionals  \
# 0                Acre                           Não informado    Conjunto 16
# 1   Rio Grande do Sul  Avenida 56 do Estado Rio Grande do Sul    Conjunto 17
# 2           São Paulo          Avenida 59 do Estado São Paulo  Não informado
# 3         Mato Grosso                           Não informado  Não informado
# 4               Bahia                Praça 56 do Estado Bahia        Apto 12
# ..                ...                                     ...            ...
# 95      Não informado                           Não informado  Não informado
# 96            Sergipe              Praça 73 do Estado Sergipe         Apto 6
# 97             Paraná                 Rua 61 do Estado Paraná        Apto 24
# 98        Mato Grosso          Praça 75 do Estado Mato Grosso  Não informado
# 99             Paraná             Avenida 19 do Estado Paraná    Conjunto 22
#
#            number
# 0   Não informado
# ...

# %% [markdown]
# Metodo Replace

# %%
#df['Coluna] = df['coluna'].replace(valor_original, valor_substituido)

# %%
df = pd.read_csv(r"C:\Users\Usuário\Documents\Arquivos_Python_Engenharia_Dados\Origem\arquivos_csv\Clientes.csv")
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Substituindo o nome de Marta para MART@ utilizando replace
df['first_name'] = df['first_name'].replace('Marta', 'MART@')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      MART@     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      MART@      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
first_name = df.loc[df['first_name'] == 'MART@']
first_name
# Out:
#     id           created_at first_name last_name            email  \
# 0    0  2017-11-01 14:45:41      MART@     Jesus              NaN
# 75  75  2018-06-21 14:28:03      MART@     Abreu              NaN
# 97  97  2018-07-04 18:45:41      MART@      Góes  marta@teste.com
#
#      cell_phone country    state                        street  number  \
# 0   9 9102-7834  Brasil     Acre                           NaN     NaN
# 75  9 9024-3467  Brasil  Roraima  Avenida 67 do Estado Roraima   410.0
# 97  9 4102-4352  Brasil   Paraná       Rua 61 do Estado Paraná   402.0
#
#     additionals
# 0   Conjunto 16
# 75  Conjunto 23
# 97      Apto 24

# %%
#Realizando a mesma função mas agora utilizando variaveis
valor_original = 'São Paulo'
valor_sub = 'SP'
df['state'] = df['state'].replace(valor_original, valor_sub)
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      MART@     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      MART@      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
df['first_name'] = df['first_name'].replace('MART@', 'Marta')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
first_name2 = df.loc[df['first_name'] == 'Marta']
first_name2
# Out:
#     id           created_at first_name last_name            email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus              NaN
# 75  75  2018-06-21 14:28:03      Marta     Abreu              NaN
# 97  97  2018-07-04 18:45:41      Marta      Góes  marta@teste.com
#
#      cell_phone country    state                        street  number  \
# 0   9 9102-7834  Brasil     Acre                           NaN     NaN
# 75  9 9024-3467  Brasil  Roraima  Avenida 67 do Estado Roraima   410.0
# 97  9 4102-4352  Brasil   Paraná       Rua 61 do Estado Paraná   402.0
#
#     additionals
# 0   Conjunto 16
# 75  Conjunto 23
# 97      Apto 24

# %%
#Realizando a alteração de varios dados de uma só vez utilizando o dicionario, que ao contrario da lista utiliza chaves {}
dicionario = {'Maranhão':'Maranhao', 'Piauí':'Piaui', 'Goiás':'Goias'}
df['state'] = df['state'].replace(dicionario)
df.head(21)
# Out:
#     id           created_at first_name    last_name                  email  \
# 0    0  2017-11-01 14:45:41      Marta        Jesus                    NaN
# 1    1  2017-10-16 00:50:39      Luana      Almeida                    NaN
# 2    2  2018-06-16 17:51:29      Frida       Mendes    frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela      Avelino    daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário     Teixeira                    NaN
# 5    5  2018-01-05 17:20:49    Marcelo      Barroso                    NaN
# 6    6  2018-06-18 11:17:42  Cristiano       Elísio  cristiano@exemplo.com
# 7    7  2018-02-08 12:36:09    Everton      Barbosa  everton@meu_email.com
# 8    8  2017-12-16 20:47:03   Gabriela        Alves   gabriela@exemplo.com
# 9    9  2018-11-11 11:48:41       Luan         Dias       luan@exemplo.com
# 10  10  2017-12-16 15:41:00    Mariana        Alves  mariana@meu_email.com
# ...
